# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('data/train.csv')
train = train.rename(columns={'feature1': 'ID'})
train.head(5)
# Out:
#          ID  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0  AG_RA_82 -0.754190  0.135971  3.652145 -0.439182 -0.292569  0.167538
# 1   AG_RA_8  0.159125  3.105914 -0.033352 -0.439182 -0.292569 -0.101824
# 2   AG_RA_3 -0.850046  1.540762  3.994327 -0.439182 -0.292569 -0.177919
# 3  AY_WH_24 -0.971159 -1.144077 -0.660518  1.504691 -0.292569 -0.207014
# 4  EI_RA_10  1.680990 -1.144077 -0.660518  2.698468 -0.292569 -0.207014
#
#    feature8  feature9  feature10  ...   target2   target3   target4   target5  \
# 0 -0.113450  2.520890   2.821957  ... -0.118733 -0.117849 -0.176014  1.295298
# 1 -0.113450 -0.215306  -0.587910  ... -0.065287 -0.198094 -0.313798 -0.343739
# 2 -0.113450  2.774934  -0.860975  ...  7.010261 -0.212774 -0.288208 -0.568998
# 3 -0.078157 -0.680928  -1.041924  ... -0.629760 -0.210968 -0.314820 -0.457470
# 4 -0.113450 -0.038464  -0.581986  ... -0.139167  3.514597  1.753230  3.060520
#
#     target6   target7   target8   target9  target10  target11
# 0 -0.033616  1.130337  0.259216 -0.265247 -0.260081 -0.241227
# 1 -0.033616 -0.305379 -0.300972 -0.265247 -0.292944 -0.191922
# 2 -0.033616 -0.744839 -0.409735 -0.265247 -0.253218 -0.284781
# 3 -0.033614 -0.622617 -0.362142 -0.139838  0.585250 -0.310475
# 4 -0.033607  0.362365  0.519133  2.196065  2.710779 -0.116691
#
# [5 rows x 26 columns]

# %%
train.isna().sum()
# Out:
# ID           0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# target1      0
# target2      0
# target3      0
# target4      0
# target5      0
# target6      0
# target7      0
# target8      0
# target9      0
# target10     0
# target11     0
# dtype: int64

# %%
train.describe()
# Out:
#          feature2    feature3    feature4    feature5    feature6    feature7  \
# count  708.000000  708.000000  708.000000  708.000000  708.000000  708.000000
# mean     0.004534    0.011594    0.029748   -0.010465   -0.020553    0.011319
# std      1.027678    0.954827    1.012775    1.000725    0.943454    1.070337
# min     -0.971159   -1.144077   -0.660518   -0.439182   -0.292569   -0.207014
# 25%     -0.878061   -0.750857   -0.660518   -0.439182   -0.292569   -0.198988
# 50%     -0.235964   -0.113401   -0.342599   -0.439182   -0.292569   -0.155492
# 75%      0.494256    0.593646    0.180802   -0.439182   -0.254536   -0.079345
# max      5.678289    5.708765    5.153338    4.540593   11.646795   14.619825
#
#          feature8    feature9   feature10   feature11  ...     target2  \
# count  708.000000  708.000000  708.000000  708.000000  ...  708.000000
# mean     0.000797    0.022297    0.007363    0.013685  ...    0.016456
# std      1.015594    1.061871    0.985771    1.118962  ...    1.057522
# min     -0.113450   -0.680928   -1.041924   -0.056403  ...   -0.682865
# 25%     -0.113450   -0.501661   -0.672541   -0.056403  ...   -0.469829
# 50%     -0.113450   -0.264029   -0.240224   -0.056403  ...   -0.309923
# 75%     -0.113450    0.170072    0.387427   -0.056403  ...    0.005452
# max     13.610531   19.246377    5.115920   20.876587  ...    8.202748
#
#           target3     target4     target5     target6     target7     target8  \
# count  708.000000  708.000000  708.000000  708.000000  708.000000  708.000000
# mean     0.020946    0.005241    0.021660   -0.033615    0.012180    0.005373
# std      1.108593    1.071973    1.024743    0.000003    1.044367    1.014289
# min     -0.256907   -0.414699   -1.296835   -0.033616   -1.191969   -0.577982
# 25%     -0.208335   -0.357077   -0.449972   -0.033616   -0.477148   -0.353171
# 50%     -0.192118   -0.308936   -0.325354   -0.033616   -0.238890   -0.280748
# 75%     -0.127986   -0.117273    0.036815   -0.033616    0.228447   -0.026765
# max     22.264151   16.751671    7.592604   -0.033586   11.027412   12.689189
#
#           target9    target10    target11
# count  708.000000  708.000000  708.000000
# mean     0.010157   -0.012080   -0.000523
# std      1.076577    1.048887    1.009011
# min     -0.265247   -0.328654   -0.394769
# 25%     -0.265247   -0.314598   -0.317776
# 50%     -0.265247   -0.297799   -0.254371
# 75%     -0.265247   -0.250095   -0.146527
# max     19.388698   21.584262   12.988439
#
# [8 rows x 25 columns]

# %%
corr = train.drop(columns='ID')
corr = corr.corr()

plt.figure(figsize=(15, 13))

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")

plt.title("Matriz de Correlação")
plt.show()

# %%
train.to_csv('data/train.csv', index=False)

# %%
X = train.drop(columns=[
    'ID', 'target1', 'target2', 'target3', 'target4', 'target5',
    'target6', 'target7', 'target8', 'target9', 'target10', 'target11'
])

corr = X.corr()

plt.figure(figsize=(15, 13))

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")

plt.title("Matriz de Correlação")
plt.show()

# %%
y = train.drop(columns=[
    'ID', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6',
    'feature7', 'feature8', 'feature9', 'feature10', 'feature11',
    'feature12', 'feature13', 'feature14', 'feature15'
])

corr = y.corr()

plt.figure(figsize=(15, 13))

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")

plt.title("Matriz de Correlação")
plt.show()
